# %%
import analyzer as raman
import bisect
import numpy as np
import pandas as pd
import os

# %%
peaks,signals,fwhm,fwhm_test,name,peak_threshold = raman.raman_batch('49thGrapheneonpCu',1200,3000,5,noise_test=True,show=False,noise_min=2200,noise_max=2400)

# %%
peak_param = {"d": [1340,1360,'auto'],
              "g": [1500,1750,9],
              "2d":[2500,2900,9],
              "total":[1000,3600,0.1,2000,2200]}

# %%
peak_data, peak_info = raman.ratio_calculator('./56thGrapheneonCu_111',**peak_param)

# %%
peak_info
# Out:
#                                              name       d_peak  d_signal  \
# 0        23112956thCu(111)withgraphene.39.dpt.txt  1346.500000  1.309787
# 1        23112956thCu(111)withgraphene.40.dpt.txt  1351.500000  0.000000
# 2        23112956thCu(111)withgraphene.35.dpt.txt  1343.500000  1.993771
# 3        23112956thCu(111)withgraphene.26.dpt.txt  1340.000000  0.000000
# 4        23112956thCu(111)withgraphene.29.dpt.txt  1340.000000  0.000000
# 5        23112956thCu(111)withgraphene.25.dpt.txt  1340.000000  0.000000
# 6        23112956thCu(111)withgraphene.19.dpt.txt  1351.000000  1.504342
# 7        23112956thCu(111)withgraphene.16.dpt.txt  1345.500000  2.068751
# 8        23112956thCu(111)withgraphene.21.dpt.txt  1340.000000  0.580620
# 9        23112956thCu(111)withgraphene.13.dpt.txt  1341.000000  1.505630
# 10        23112956thCu(111)withgraphene.8.dpt.txt  1340.000000  0.000000
# 11       23112956thCu(111)withgraphene.38.dpt.txt  1343.000000  1.122654
# ...
